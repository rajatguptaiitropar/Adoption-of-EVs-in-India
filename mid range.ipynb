# %%
# !pip install tensorflow==2.15
# !pip install scikit-learn
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.15
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# ============================================================
# 🚗 EV Adoption Model - Neural Network (85/15 Stratified Split, Seed=42)
# ============================================================

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers, callbacks

# --- Reproducibility ---
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
np.set_printoptions(precision=4, suppress=True)

# --- Load full dataset ---
data_path = r'/content/Midrange_binary.csv'
df = pd.read_csv(data_path)
print(f"Loaded dataset: {len(df)} rows, {len(df.columns)} columns")

# --- Define variables ---
continuous_features = ['ev_price_n', 'ev_fueln1', 'ev_rangen1', 'ev_loan', 'ev_reg1','age','income']
categorical_features = ['EV_Initial', 'EV_Ban', 'ev_res1', 'ev_res2','gender']
target_col = 'ev'

# --- Stratified 85/15 split (same as Biogeme setup) ---
train_df, valid_df = train_test_split(
    df,
    test_size=0.15,
    random_state=42,     # fixed seed for reproducibility
    stratify=df['ev']    # maintain same class proportion
)
print(f"Train shape: {train_df.shape}, Validation shape: {valid_df.shape}")

# --- Map target: 1 → conventional (0), 2 → EV (1) ---
def map_target(s):
    return np.where(s == 2, 1, 0)

y_train = map_target(train_df[target_col].values)
y_valid = map_target(valid_df[target_col].values)

# --- Class balance check ---
print("\nClass balance (training):")
print(pd.Series(y_train).value_counts(normalize=True))
print("\nClass balance (validation):")
print(pd.Series(y_valid).value_counts(normalize=True))

# --- Scale continuous vars (fit on train, apply to valid) ---
scaler = StandardScaler()
X_train_cont = scaler.fit_transform(train_df[continuous_features])
X_valid_cont = scaler.transform(valid_df[continuous_features])

# --- Keep categorical features as-is ---
X_train_cat = train_df[categorical_features].astype(float).values
X_valid_cat = valid_df[categorical_features].astype(float).values

# --- Combine features ---
X_train = np.concatenate([X_train_cont, X_train_cat], axis=1)
X_valid = np.concatenate([X_valid_cont, X_valid_cat], axis=1)

input_dim = X_train.shape[1]
print(f"\n✅ Final input dimension: {input_dim}")

# --- Compute class weights ---
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))
print("\nClass weights:", class_weights)

# --- Build Keras model factory ---
def build_model(n_layers=2, n_units=64, activation='relu', dropout_rate=0.2,
                optimizer='adam', learning_rate=1e-3, input_dim=None):
    if input_dim is None:
        raise ValueError("input_dim must be specified")

    model = models.Sequential()
    model.add(layers.Input(shape=(input_dim,)))
    for _ in range(int(n_layers)):
        model.add(layers.Dense(int(n_units), activation=activation))
        if dropout_rate > 0:
            model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(1, activation='sigmoid'))

    if optimizer == 'adam':
        opt = optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    else:
        opt = optimizer

    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# --- Define hyperparameter search space ---
param_dist = {
    'n_layers': [1, 2, 3, 4],
    'n_units': [5, 6, 7, 8, 16, 32, 64],
    'activation': ['relu', 'tanh'],
    'dropout_rate': [0.0, 0.05, 0.1, 0.2],
    'optimizer': ['adam', 'sgd'],
    'learning_rate': [0.1, 1e-2, 1e-3, 1e-4],
    'batch_size': [32, 40, 64],
    'epochs': [50, 100]
}

# --- Helper to sample random hyperparameters ---
def sample_params(param_dict):
    return {k: random.choice(v) for k, v in param_dict.items()}

# --- Early stopping ---
early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True,
    verbose=1
)

# --- Manual randomized search ---
n_iter = 50  # number of random hyperparameter trials
best_val_acc = 0
best_params = None
best_model = None

print(f"\n🚀 Starting manual randomized search for {n_iter} combinations...\n")

for i in range(n_iter):
    params = sample_params(param_dist)
    print(f"\n🧪 Trial {i+1}/{n_iter}: {params}")

    # Extract fit parameters
    fit_params = {
        'epochs': params.pop('epochs'),
        'batch_size': params.pop('batch_size')
    }

    model = build_model(input_dim=input_dim, **params)

    history = model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        class_weight=class_weights,
        **fit_params,
        callbacks=[early_stop],
        verbose=1
    )

    best_epoch = np.argmax(history.history['val_accuracy'])
    val_acc = history.history['val_accuracy'][best_epoch]
    val_loss = history.history['val_loss'][best_epoch]

    print(f"✅ Best epoch: {best_epoch+1}")
    print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_params = params
        best_model = model

print("\n✅ Best Parameters Found:")
print(best_params)
print(f"Best Validation Accuracy: {best_val_acc:.4f}")

# --- Final evaluation on validation data ---
prob_valid = best_model.predict(X_valid).reshape(-1)
pred_valid = (prob_valid >= 0.5).astype(int)

acc = accuracy_score(y_valid, pred_valid)
auc = roc_auc_score(y_valid, prob_valid)
conf_mat = confusion_matrix(y_valid, pred_valid)

print("\n📊 Final Validation Results:")
print(f"Accuracy: {acc*100:.2f}%")
print(f"AUC: {auc:.4f}")
print("Confusion Matrix:\n", conf_mat)

# --- Plot predicted probability distribution ---
plt.hist(prob_valid, bins=30, color='skyblue', edgecolor='black')
plt.title("Predicted probabilities on validation set")
plt.xlabel("Predicted probability (EV)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# --- Probability summary ---
print("\nPredicted Probability Summary:")
print(pd.Series(prob_valid).describe())

# --- Utility-like logits ---
logits = np.log(prob_valid / (1 - prob_valid))
print("\n🔍 First 15 utility-like values:")
for i in range(min(15, len(prob_valid))):
    print(f"{i:2d}: prob={prob_valid[i]:.4f}, logit={logits[i]:.4f}, actual={y_valid[i]}")

# --- Save best model ---
best_model.save('best_nn_ev_model.keras')
print("\n✅ Model saved as 'best_nn_ev_model.keras'")
# Out:
# Loaded dataset: 968 rows, 32 columns
# Train shape: (822, 32), Validation shape: (146, 32)
#
# Class balance (training):
# 1    0.812652
# 0    0.187348
# Name: proportion, dtype: float64
#
# Class balance (validation):
# 1    0.815068
# 0    0.184932
# Name: proportion, dtype: float64
#
# ✅ Final input dimension: 12
#
# Class weights: {0: np.float64(2.668831168831169), 1: np.float64(0.6152694610778443)}
#
# 🚀 Starting manual randomized search for 50 combinations...
#
#
# 🧪 Trial 1/50: {'n_layers': 1, 'n_units': 5, 'activation': 'tanh', 'dropout_rate': 0.05, 'optimizer': 'adam', 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 50}
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5083 - loss: 0.7647 - val_accuracy: 0.5685 - val_loss: 0.6698
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5412 - loss: 0.7176 - val_accuracy: 0.5411 - val_loss: 0.6938
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5404 - loss: 0.6899 - val_accuracy: 0.6370 - val_loss: 0.6508
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5868 - loss: 0.6819 - val_accuracy: 0.6781 - val_loss: 0.6171
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6291 - loss: 0.6542 - val_accuracy: 0.6233 - val_loss: 0.6618
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5530 - loss: 0.6666 - val_accuracy: 0.6301 - val_loss: 0.6678
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5807 - loss: 0.6521 - val_accuracy: 0.6438 - val_loss: 0.6419
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5860 - loss: 0.6719 - val_accuracy: 0.6301 - val_loss: 0.6573
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5983 - loss: 0.6678 - val_accuracy: 0.6301 - val_loss: 0.6495
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6053 - loss: 0.6580 - val_accuracy: 0.6370 - val_loss: 0.6387
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 4.
# ✅ Best epoch: 4
# Val Loss: 0.6171, Val Acc: 0.6781
#
# 🧪 Trial 2/50: {'n_layers': 1, 'n_units': 16, 'activation': 'tanh', 'dropout_rate': 0.0, 'optimizer': 'adam', 'learning_rate': 0.1, 'batch_size': 32, 'epochs': 50}
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5514 - loss: 0.8464 - val_accuracy: 0.7329 - val_loss: 0.5883
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6554 - loss: 0.6526 - val_accuracy: 0.5822 - val_loss: 0.6955
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6456 - loss: 0.5971 - val_accuracy: 0.6301 - val_loss: 0.6871
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5948 - loss: 0.6581 - val_accuracy: 0.7123 - val_loss: 0.5645
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6768 - loss: 0.6454 - val_accuracy: 0.4315 - val_loss: 0.8604
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6002 - loss: 0.6520 - val_accuracy: 0.6507 - val_loss: 0.5937
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6857 - loss: 0.6691 - val_accuracy: 0.6918 - val_loss: 0.6095
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6876 - loss: 0.6334 - val_accuracy: 0.5205 - val_loss: 0.9199
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5873 - loss: 0.6755 - val_accuracy: 0.7397 - val_loss: 0.5376
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6851 - loss: 0.5941 - val_accuracy: 0.6164 - val_loss: 0.6954
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6341 - loss: 0.6134 - val_accuracy: 0.7055 - val_loss: 0.5638
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6775 - loss: 0.6320 - val_accuracy: 0.5616 - val_loss: 0.7807
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6639 - loss: 0.6028 - val_accuracy: 0.5890 - val_loss: 0.7117
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6391 - loss: 0.6300 - val_accuracy: 0.6575 - val_loss: 0.6369
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6571 - loss: 0.6667 - val_accuracy: 0.5137 - val_loss: 0.9399
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 9.
# ✅ Best epoch: 9
# Val Loss: 0.5376, Val Acc: 0.7397
#
# 🧪 Trial 3/50: {'n_layers': 1, 'n_units': 16, 'activation': 'relu', 'dropout_rate': 0.2, 'optimizer': 'adam', 'learning_rate': 0.0001, 'batch_size': 64, 'epochs': 100}
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5050 - loss: 0.7230 - val_accuracy: 0.5000 - val_loss: 0.7311
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4873 - loss: 0.7368 - val_accuracy: 0.5068 - val_loss: 0.7276
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4581 - loss: 0.7029 - val_accuracy: 0.5068 - val_loss: 0.7236
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5249 - loss: 0.7511 - val_accuracy: 0.5137 - val_loss: 0.7215
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5083 - loss: 0.7037 - val_accuracy: 0.5137 - val_loss: 0.7186
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5232 - loss: 0.7186 - val_accuracy: 0.5205 - val_loss: 0.7159
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4672 - loss: 0.7174 - val_accuracy: 0.5205 - val_loss: 0.7127
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4985 - loss: 0.6566 - val_accuracy: 0.5205 - val_loss: 0.7097
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4990 - loss: 0.6918 - val_accuracy: 0.5342 - val_loss: 0.7076
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5270 - loss: 0.7027 - val_accuracy: 0.5342 - val_loss: 0.7061
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4869 - loss: 0.7044 - val_accuracy: 0.5342 - val_loss: 0.7041
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4700 - loss: 0.7496 - val_accuracy: 0.5411 - val_loss: 0.7025
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5027 - loss: 0.7058 - val_accuracy: 0.5548 - val_loss: 0.7001
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5438 - loss: 0.6842 - val_accuracy: 0.5616 - val_loss: 0.6986
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5360 - loss: 0.6755 - val_accuracy: 0.6233 - val_loss: 0.6904
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5903 - loss: 0.7096 - val_accuracy: 0.6712 - val_loss: 0.6450
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6496 - loss: 0.6471 - val_accuracy: 0.6438 - val_loss: 0.6510
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6741 - loss: 0.6373 - val_accuracy: 0.6712 - val_loss: 0.6355
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6847 - loss: 0.6261 - val_accuracy: 0.3836 - val_loss: 0.8745
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5073 - loss: 0.6650 - val_accuracy: 0.6575 - val_loss: 0.6715
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6904 - loss: 0.6251 - val_accuracy: 0.6370 - val_loss: 0.6649
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6165 - loss: 0.6374 - val_accuracy: 0.5685 - val_loss: 0.6563
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6651 - loss: 0.6465 - val_accuracy: 0.4863 - val_loss: 0.7209
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5635 - loss: 0.6519 - val_accuracy: 0.6301 - val_loss: 0.6135
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6803 - loss: 0.6065 - val_accuracy: 0.6438 - val_loss: 0.6576
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7071 - loss: 0.6060 - val_accuracy: 0.6233 - val_loss: 0.6680
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6681 - loss: 0.6312 - val_accuracy: 0.5411 - val_loss: 0.7008
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6078 - loss: 0.6373 - val_accuracy: 0.5959 - val_loss: 0.6473
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6630 - loss: 0.6340 - val_accuracy: 0.6438 - val_loss: 0.6464
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6751 - loss: 0.5924 - val_accuracy: 0.3288 - val_loss: 0.8850
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 17.
# ✅ Best epoch: 9
# Val Loss: 0.6450, Val Acc: 0.6712
#
# 🧪 Trial 6/50: {'n_layers': 3, 'n_units': 16, 'activation': 'relu', 'dropout_rate': 0.0, 'optimizer': 'adam', 'learning_rate': 0.01, 'batch_size': 40, 'epochs': 50}
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5173 - loss: 0.7420 - val_accuracy: 0.6918 - val_loss: 0.6200
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6444 - loss: 0.6605 - val_accuracy: 0.5548 - val_loss: 0.6687
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6052 - loss: 0.6722 - val_accuracy: 0.6027 - val_loss: 0.6481
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6625 - loss: 0.6604 - val_accuracy: 0.6301 - val_loss: 0.6771
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6961 - loss: 0.6076 - val_accuracy: 0.5342 - val_loss: 0.7356
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5443 - loss: 0.6476 - val_accuracy: 0.5890 - val_loss: 0.6798
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6526 - loss: 0.6255 - val_accuracy: 0.6644 - val_loss: 0.6453
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Best epoch: 1
# Val Loss: 0.6200, Val Acc: 0.6918
#
# 🧪 Trial 7/50: {'n_layers': 4, 'n_units': 7, 'activation': 'tanh', 'dropout_rate': 0.1, 'optimizer': 'adam', 'learning_rate': 0.001, 'batch_size': 40, 'epochs': 50}
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4481 - loss: 0.7351 - val_accuracy: 0.5000 - val_loss: 0.7006
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4788 - loss: 0.7157 - val_accuracy: 0.5068 - val_loss: 0.6852
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5317 - loss: 0.7151 - val_accuracy: 0.5205 - val_loss: 0.6713
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5445 - loss: 0.6855 - val_accuracy: 0.5959 - val_loss: 0.6553
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6045 - loss: 0.6674 - val_accuracy: 0.5890 - val_loss: 0.6663
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5717 - loss: 0.6844 - val_accuracy: 0.5548 - val_loss: 0.6766
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5536 - loss: 0.6759 - val_accuracy: 0.5548 - val_loss: 0.6774
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4826 - loss: 0.7101 - val_accuracy: 0.5685 - val_loss: 0.6706
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5264 - loss: 0.6787 - val_accuracy: 0.5822 - val_loss: 0.6667
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5715 - loss: 0.6426 - val_accuracy: 0.5890 - val_loss: 0.6655
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 4.
# ✅ Best epoch: 4
# Val Loss: 0.6553, Val Acc: 0.5959
#
# 🧪 Trial 8/50: {'n_layers': 2, 'n_units': 6, 'activation': 'tanh', 'dropout_rate': 0.2, 'optimizer': 'sgd', 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 100}
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5473 - loss: 0.7334 - val_accuracy: 0.5616 - val_loss: 0.7053
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5014 - loss: 0.7188 - val_accuracy: 0.3767 - val_loss: 0.7293
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4403 - loss: 0.7310 - val_accuracy: 0.4589 - val_loss: 0.7013
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5491 - loss: 0.7246 - val_accuracy: 0.6164 - val_loss: 0.6615
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5486 - loss: 0.7056 - val_accuracy: 0.6027 - val_loss: 0.6674
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5660 - loss: 0.6825 - val_accuracy: 0.5068 - val_loss: 0.6930
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4826 - loss: 0.7046 - val_accuracy: 0.5068 - val_loss: 0.6968
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5253 - loss: 0.6852 - val_accuracy: 0.5205 - val_loss: 0.6939
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5146 - loss: 0.6952 - val_accuracy: 0.5342 - val_loss: 0.6832
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5319 - loss: 0.7018 - val_accuracy: 0.5890 - val_loss: 0.6730
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 4.
# ✅ Best epoch: 4
# Val Loss: 0.6615, Val Acc: 0.6164
#
# 🧪 Trial 9/50: {'n_layers': 1, 'n_units': 64, 'activation': 'tanh', 'dropout_rate': 0.2, 'optimizer': 'sgd', 'learning_rate': 0.1, 'batch_size': 32, 'epochs': 100}
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4927 - loss: 0.7569 - val_accuracy: 0.8219 - val_loss: 0.5129
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6095 - loss: 0.7805 - val_accuracy: 0.3699 - val_loss: 0.7790
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4771 - loss: 0.7053 - val_accuracy: 0.4932 - val_loss: 0.7432
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4897 - loss: 0.7624 - val_accuracy: 0.6644 - val_loss: 0.6085
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6147 - loss: 0.7050 - val_accuracy: 0.5479 - val_loss: 0.7188
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5729 - loss: 0.6976 - val_accuracy: 0.2945 - val_loss: 0.9263
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4976 - loss: 0.7294 - val_accuracy: 0.7603 - val_loss: 0.5445
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Best epoch: 1
# Val Loss: 0.5129, Val Acc: 0.8219
#
# 🧪 Trial 10/50: {'n_layers': 4, 'n_units': 32, 'activation': 'tanh', 'dropout_rate': 0.05, 'optimizer': 'sgd', 'learning_rate': 0.01, 'batch_size': 32, 'epochs': 100}
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5336 - loss: 0.7099 - val_accuracy: 0.7329 - val_loss: 0.6030
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7034 - loss: 0.6956 - val_accuracy: 0.4110 - val_loss: 0.7412
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5452 - loss: 0.6632 - val_accuracy: 0.5205 - val_loss: 0.6989
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4897 - loss: 0.7044 - val_accuracy: 0.7192 - val_loss: 0.5928
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6178 - loss: 0.7283 - val_accuracy: 0.6986 - val_loss: 0.6321
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6345 - loss: 0.6616 - val_accuracy: 0.5822 - val_loss: 0.6802
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5170 - loss: 0.6928 - val_accuracy: 0.6918 - val_loss: 0.6304
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5949 - loss: 0.6384 - val_accuracy: 0.6781 - val_loss: 0.6555
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4527 - loss: 0.7017 - val_accuracy: 0.7123 - val_loss: 0.6110
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5674 - loss: 0.7120 - val_accuracy: 0.6781 - val_loss: 0.6137
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 4.
# ✅ Best epoch: 1
# Val Loss: 0.6030, Val Acc: 0.7329
#
# 🧪 Trial 11/50: {'n_layers': 4, 'n_units': 5, 'activation': 'relu', 'dropout_rate': 0.0, 'optimizer': 'adam', 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 100}
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4847 - loss: 0.6899 - val_accuracy: 0.5274 - val_loss: 0.7164
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5046 - loss: 0.7093 - val_accuracy: 0.5274 - val_loss: 0.7156
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5253 - loss: 0.7119 - val_accuracy: 0.5274 - val_loss: 0.7152
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5070 - loss: 0.7029 - val_accuracy: 0.5342 - val_loss: 0.7146
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4808 - loss: 0.7113 - val_accuracy: 0.5342 - val_loss: 0.7141
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4945 - loss: 0.6994 - val_accuracy: 0.5479 - val_loss: 0.7135
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5191 - loss: 0.6875 - val_accuracy: 0.5479 - val_loss: 0.7129
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5024 - loss: 0.7211 - val_accuracy: 0.5411 - val_loss: 0.7125
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5105 - loss: 0.6682 - val_accuracy: 0.5342 - val_loss: 0.7118
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5351 - loss: 0.6978 - val_accuracy: 0.5342 - val_loss: 0.7116
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5112 - loss: 0.7021 - val_accuracy: 0.5342 - val_loss: 0.7108
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5381 - loss: 0.6752 - val_accuracy: 0.5342 - val_loss: 0.7102
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5249 - loss: 0.6988 - val_accuracy: 0.5342 - val_loss: 0.7100
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5251 - loss: 0.6993 - val_accuracy: 0.5342 - val_loss: 0.7096
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5262 - loss: 0.7000 - val_accuracy: 0.5274 - val_loss: 0.7091
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5296 - loss: 0.6709 - val_accuracy: 0.5274 - val_loss: 0.7086
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5293 - loss: 0.7037 - val_accuracy: 0.5274 - val_loss: 0.7080
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5372 - loss: 0.6753 - val_accuracy: 0.5342 - val_loss: 0.7076
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5302 - loss: 0.7154 - val_accuracy: 0.5411 - val_loss: 0.7072
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5410 - loss: 0.6901 - val_accuracy: 0.5479 - val_loss: 0.7068
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5042 - loss: 0.6924 - val_accuracy: 0.5548 - val_loss: 0.7065
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5100 - loss: 0.6678 - val_accuracy: 0.5685 - val_loss: 0.7061
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5530 - loss: 0.7023 - val_accuracy: 0.5685 - val_loss: 0.7057
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5534 - loss: 0.6837 - val_accuracy: 0.5753 - val_loss: 0.7054
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5321 - loss: 0.6852 - val_accuracy: 0.5753 - val_loss: 0.7054
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5504 - loss: 0.7066 - val_accuracy: 0.5753 - val_loss: 0.7051
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5826 - loss: 0.6743 - val_accuracy: 0.5753 - val_loss: 0.7046
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5620 - loss: 0.6757 - val_accuracy: 0.5890 - val_loss: 0.7042
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5630 - loss: 0.7305 - val_accuracy: 0.5890 - val_loss: 0.7042
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5454 - loss: 0.6948 - val_accuracy: 0.5890 - val_loss: 0.7038
# Restoring model weights from the end of the best epoch: 50.
# ✅ Best epoch: 48
# Val Loss: 0.7042, Val Acc: 0.5890
#
# ✅ Best Parameters Found:
# {'n_layers': 1, 'n_units': 64, 'activation': 'tanh', 'dropout_rate': 0.2, 'optimizer': 'sgd', 'learning_rate': 0.1}
# Best Validation Accuracy: 0.8219
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# 📊 Final Validation Results:
# Accuracy: 82.19%
# AUC: 0.5764
# Confusion Matrix:
#  [[  2  25]
#  [  1 118]]
# Predicted Probability Summary:
# count    146.000000
# mean       0.692010
# std        0.083567
# min        0.434883
# 25%        0.643992
# 50%        0.709579
# 75%        0.748031
# max        0.840711
# dtype: float64
#
# 🔍 First 15 utility-like values:
#  0: prob=0.5589, logit=0.2368, actual=0
#  1: prob=0.7693, logit=1.2042, actual=1
#  2: prob=0.5768, logit=0.3098, actual=1
#  3: prob=0.6048, logit=0.4256, actual=0
#  4: prob=0.7567, logit=1.1346, actual=1
#  5: prob=0.6033, logit=0.4192, actual=1
#  6: prob=0.6334, logit=0.5470, actual=1
#  7: prob=0.6916, logit=0.8078, actual=1
#  8: prob=0.5066, logit=0.0263, actual=1
#  9: prob=0.6816, logit=0.7611, actual=1
# 10: prob=0.8072, logit=1.4317, actual=1
# 11: prob=0.7575, logit=1.1392, actual=0
# 12: prob=0.8407, logit=1.6635, actual=0
# 13: prob=0.6651, logit=0.6861, actual=0
# 14: prob=0.8108, logit=1.4551, actual=1
#
# ✅ Model saved as 'best_nn_ev_model.keras'

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
# ============================================================
# 📊 SHAP Explainability for EV Adoption Neural Network (Fixed 3D Output)
# ============================================================

import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import textwrap
# --- Feature names (match model input order) ---
feature_names = [
    'ev_price_n', 'ev_fueln1', 'ev_rangen1', 'ev_loan', 'ev_reg1',
    'age', 'income', 'EV_Initial', 'EV_Ban', 'ev_res1', 'ev_res2', 'gender'
]

# --- Pretty names for plots ---
pretty_names = [
    'Price EV - Price CV',
    'EV fuel cost (/100 km) - CV fuel cost (/100 km)',
    'Range EV - Range CV',
    'Purchase interest rate - CV purchase interest rate',
    'Registration fee discount',
    'Age',
    'Income',
    'EV Initial',
    'EV Ban',
    'Reserved parking (condition 1)',
    'Reserved parking (condition 2)',
    'Gender'
]

assert len(feature_names) == X_valid.shape[1], "⚠️ Feature count mismatch!"

# --- SHAP explainer ---
try:
    print("🔍 Using DeepExplainer...")
    explainer = shap.DeepExplainer(best_model, X_train[:500])
    shap_values = explainer.shap_values(X_valid[:1000])

    if isinstance(shap_values, list):
        shap_values = shap_values[0]

    shap_values = np.array(shap_values)

    # ✅ FIX: squeeze (256, 12, 1) → (256, 12)
    if shap_values.ndim == 3 and shap_values.shape[-1] == 1:
        shap_values = shap_values.squeeze(-1)
        print(f"🔧 Squeezed SHAP values to shape: {shap_values.shape}")

except Exception as e:
    print(f"⚠️ DeepExplainer failed ({e}), switching to KernelExplainer (slower)...")
    background = X_train[np.random.choice(X_train.shape[0], 100, replace=False)]
    explainer = shap.KernelExplainer(best_model.predict, background)
    shap_values = explainer.shap_values(X_valid[:500])
    shap_values = shap_values[0]

# --- Create DataFrame ---
shap_df = pd.DataFrame(shap_values, columns=feature_names)

print("\n📈 Mean absolute SHAP values (feature importance):")
print(shap_df.abs().mean().sort_values(ascending=False))

# --- SHAP Summary Plot ---
plt.figure(figsize=(10, 6))
shap.summary_plot(
    shap_values,
    X_valid[:len(shap_values)],
    feature_names=pretty_names,
    show=False
)
# --- Set font globally to Times New Roman ---
mpl.rcParams['font.family'] = 'Times New Roman'
mpl.rcParams['font.size'] = 12

# --- SHAP Summary Plot ---
plt.figure(figsize=(10, 6))
shap.summary_plot(
    shap_values,
    X_valid[:len(shap_values)],
    feature_names=pretty_names,
    show=False
)
plt.title("Feature Importance via SHAP Values", fontsize=16, fontname='Times New Roman')
plt.tight_layout()
plt.show()

# --- SHAP Bar Plot (Mean |SHAP|) ---
mean_abs = np.abs(shap_values).mean(axis=0)
importance_df = pd.DataFrame({'Feature': pretty_names, 'Mean |SHAP|': mean_abs})
importance_df = importance_df.sort_values('Mean |SHAP|', ascending=True)

# Wrap long labels to 2 lines (≈30 characters per line)
importance_df['Feature_wrapped'] = [
    textwrap.fill(f, width=30, break_long_words=False) for f in importance_df['Feature']
]

plt.figure(figsize=(8, 6))
plt.barh(importance_df['Feature_wrapped'], importance_df['Mean |SHAP|'])
plt.xlabel("Mean |SHAP value|", fontname='Times New Roman', fontsize=13)
plt.ylabel("")
plt.title("Average Feature Importance (SHAP)", fontname='Times New Roman', fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# 🔍 Using DeepExplainer...
# /usr/local/lib/python3.12/dist-packages/shap/explainers/_deep/deep_tf.py:94: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_118
# Received: inputs=['Tensor(shape=(500, 12))']
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_118
# Received: inputs=['Tensor(shape=(1000, 12))']
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_118
# Received: inputs=['Tensor(shape=(146, 12))']
#   warnings.warn(msg)
# /tmp/ipython-input-3307350688.py:66: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# /tmp/ipython-input-3307350688.py:78: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# 🔧 Squeezed SHAP values to shape: (146, 12)
#
# 📈 Mean absolute SHAP values (feature importance):
# ev_reg1       0.051538
# ev_rangen1    0.043744
# ev_price_n    0.042081
# ev_loan       0.039114
# EV_Initial    0.027527
# ev_fueln1     0.025801
# EV_Ban        0.023463
# ev_res2       0.019350
# income        0.016049
# ev_res1       0.012666
# age           0.011564
# gender        0.000000
# dtype: float64
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

# --- Plot font setup ---
rcParams['font.family'] = 'Times New Roman'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

# --- Feature name map (same as before) ---
feature_pretty = {
    'ev_price_n': 'Price EV - Price CV',
    'ev_fueln1': 'EV fuel cost (/100 km) - CV fuel cost (/100 km)',
    'ev_rangen1': 'Range EV - Range CV',
    'ev_loan': 'Purchase interest rate (EV - CV)',
    'ev_reg1': 'Registration fee discount',
    'ev_res1': 'Reserved parking (condition1)',
    'ev_res2': 'Reserved parking (condition2)',
    'gender': 'Gender',
    'income': 'Income',
    'age': 'Age',
    'EV_Initial': 'Initial Ownership / Upfront EV Incentive',
    'EV_Ban': 'Ban on CVs'
}

feature_names = ['ev_price_n', 'ev_fueln1', 'ev_rangen1',
                 'ev_loan', 'ev_reg1', 'age', 'income',
                 'EV_Initial', 'EV_Ban', 'ev_res1', 'ev_res2', 'gender']

# --- Sensitivity Function ---
def sensitivity_feature_change(model, X_base, feature_names, pretty_names,
                               var_name='EV_Initial', values=[0.5, 1.0, 1.5, 2.0, 3.0]):
    """
    Replaces all values of a selected feature (e.g., EV_Initial)
    with given constants and computes mean predicted EV probability.
    """
    idx = feature_names.index(var_name)
    results = []

    for val in values:
        X_temp = X_base.copy()
        X_temp[:, idx] = val   # replace column with a fixed value
        preds = model.predict(X_temp, verbose=0).mean()
        results.append({'feature_value': val, 'Predicted_EV_Prob': preds})

    df_results = pd.DataFrame(results)

    # --- Plot ---
    plt.figure(figsize=(7, 5))
    plt.plot(df_results['feature_value'], df_results['Predicted_EV_Prob'],
             marker='o', linestyle='-', color='darkgreen')
    plt.title(f"Sensitivity to {pretty_names[var_name]}", fontsize=14)
    plt.xlabel(f"{pretty_names[var_name]} (fixed values)")
    plt.ylabel("Average Predicted Probability of Choosing EV")
    plt.grid(True, alpha=0.4)
    plt.tight_layout()
    plt.show()

    return df_results

# --- Run analysis for EV_Initial ---
sensitivity_EVInitial = sensitivity_feature_change(
    model=best_model,
    X_base=X_valid,
    feature_names=feature_names,
    pretty_names=feature_pretty,
    var_name='EV_Initial',
    values=[0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
)

print("\n📊 Sensitivity to EV_Initial (Upfront EV Incentive):")
print(sensitivity_EVInitial)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# 📊 Sensitivity to EV_Initial (Upfront EV Incentive):
#    feature_value  Predicted_EV_Prob
# 0            0.5           0.589941
# 1            1.0           0.623658
# 2            1.5           0.654911
# 3            2.0           0.683121
# 4            2.5           0.707990
# 5            3.0           0.729467

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

# --- Style ---
rcParams['font.family'] = 'Times New Roman'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

feature_pretty = {
    'ev_price_n': 'Price EV - Price CV',
    'ev_fueln1': 'EV fuel cost (/100 km) - CV fuel cost (/100 km)',
    'ev_rangen1': 'Range EV - Range CV',
    'ev_loan': 'Purchase interest rate (EV - CV)',
    'ev_reg1': 'Registration fee discount',
    'ev_res1': 'Reserved parking (condition1)',
    'ev_res2': 'Reserved parking (condition2)',
    'gender': 'Gender',
    'income': 'Income',
    'age': 'Age',
    'EV_Initial': 'Initial Ownership',
    'EV_Ban': 'Ban on CVs'
}

feature_names = ['ev_price_n', 'ev_fueln1', 'ev_rangen1',
                 'ev_loan', 'ev_reg1', 'age', 'income',
                 'EV_Initial', 'EV_Ban', 'ev_res1', 'ev_res2', 'gender']

def sensitivity_ev_price(model, X_base, feature_names, pretty_names, var_name='ev_price_n',
                         num_points=30, scale_range=(1.0, 0.5)):
    idx = feature_names.index(var_name)
    scales = np.linspace(scale_range[0], scale_range[1], num_points)
    preds = []

    for s in scales:
        X_temp = X_base.copy()
        X_temp[:, idx] = X_base[:, idx] * s
        p = model.predict(X_temp, verbose=0).mean()
        preds.append(p)

    plt.figure(figsize=(7, 5))
    plt.plot((1 - scales) * 100, preds, lw=2, color='darkblue')
    plt.title(f"Sensitivity to EV Price Difference\n({pretty_names[var_name]})", fontsize=14)
    plt.xlabel("Decrease in EV Price Difference (%)")
    plt.ylabel("Predicted Probability of Choosing EV")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    sensitivity_df = pd.DataFrame({
        'Price_Decrease_%': (1 - scales) * 100,
        'Predicted_EV_Prob': preds
    })
    return sensitivity_df

# --- Run analysis ---
sensitivity_df = sensitivity_ev_price(
    model=best_model,
    X_base=X_valid,
    feature_names=feature_names,
    pretty_names=feature_pretty,
    var_name='ev_price_n',
    num_points=40,
    scale_range=(1.0, 0.5)
)

print("\n📊 Sensitivity results (sample):")
print(sensitivity_df.head(10))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# 📊 Sensitivity results (sample):
#    Price_Decrease_%  Predicted_EV_Prob
# 0          0.000000           0.692010
# 1          1.282051           0.691906
# 2          2.564103           0.691800
# 3          3.846154           0.691693
# 4          5.128205           0.691584
# 5          6.410256           0.691474
# 6          7.692308           0.691363
# 7          8.974359           0.691251
# 8         10.256410           0.691137
# 9         11.538462           0.691021
